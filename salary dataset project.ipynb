# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %% [markdown]
# ### EDA

# %%
sns.scatterplot(x='rank',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %% [markdown]
# We can see professors have highest salaries ,than assocprof,than asstprof

# %%
sns.scatterplot(x='rank',y='sex',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='sex'>

# %%
sns.scatterplot(x='salary',y='yrs.service',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='yrs.service'>

# %% [markdown]
# we can see the salaries increases with increase in experience

# %%
sns.scatterplot(x='discipline',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x='salary',y='sex',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sex'>

# %%
sns.scatterplot(x='salary',y='yrs.service',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='yrs.service'>

# %% [markdown]
# we can see the salaries increase with increase in years of service

# %%
sns.scatterplot(x='yrs.since.phd',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %% [markdown]
# we can see the salaries increase with increase in years since phd

# %%
sns.pairplot(df)

# %% [markdown]
# ### correlation

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# yr.sevice contributing good amount with target variable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %% [markdown]
# ### Outliers

# %%
plt.boxplot(df.salary)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x201af8f11c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x201af8f1820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x201af8dfd30>],
#  'medians': [<matplotlib.lines.Line2D at 0x201af8f1f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x201af8fd310>],
#  'means': []}

# %%
collist=df.columns.values
ncol=6
nrows=397
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4700/2802552961.py in <module>
#       5 for i in range(0,len(collist)):
#       6     plt.subplot(nrows,ncol,i+1)
# ----> 7     sns.boxplot(df[collist[i]],color='green',orient='v')
#       8     plt.tight_layout()
#
# ...

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
df.scew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4700/3716257859.py in <module>
# ----> 1 df.scew()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scew'
